# %%
def vow_replace(s,v):
    l = ['a','e','i','o','u']
    a = ''
    s = s.lower()
    for i in s:
        if i in l:
            i = v
        a = a+i
    return a

s = "cheese casserole"
v = 'o'
print(vow_replace(s,v))
# Out:
# chooso cossorolo
