# %%
def dict_to_list(a):
    b = sorted(a)
    d = []
    for i in b:
        c = [i,a[i]]
        d.append(tuple(c))
    return d

d = {"likes": 2,"dislikes": 3,"followers": 10}
print(dict_to_list(d))
# Out:
# [('dislikes', 3), ('followers', 10), ('likes', 2)]
