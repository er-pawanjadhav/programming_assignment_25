# %%
def ascii_capitalize(s):
    s1 = ''
    for i in s:
        c = ord(i)
        if c%2==0:
            i = i.upper()
        else:
            i = i.lower()
        s1 = s1+i
    return s1
s = "THE LITTLE MERMAID"
print(ascii_capitalize(s))
# Out:
# THe LiTTLe meRmaiD
