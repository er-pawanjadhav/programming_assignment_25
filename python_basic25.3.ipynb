# %%
def mapping(a):
    d = {}
    for i in a:
        if i.islower():
            d[i] = i.upper()
        else:
            return i, "only lower case letter accept"
    return d
    
l = ["a", "v", "y", "z"]
print(mapping(l) )
# Out:
# {'a': 'A', 'v': 'V', 'y': 'Y', 'z': 'Z'}
